# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import pylab as pl
import shapely
import os
import statsmodels as stm
#import urllib2
import urllib
#import StringIO
import ast
from datetime import datetime, timedelta
import time
import io
import json
import requests
import shutil
import datetime as dt
from sklearn.cluster import KMeans
from scipy.cluster.vq import whiten
from sklearn import preprocessing
import statsmodels.formula.api as smf
import pytz as pytz

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ---

# %% [markdown]
# # WEATHER

# %%
# Downloadind the weather data - don't run again
#!unzip "DarkSky_Data.zip"

# %%
# Reading in the weather 

weather = pd.read_json("DarkSky_Data.json")

# %%
weather.head()
# Out:
#    apparentTemperature  cloudCover  dewPoint  humidity                 icon  \
# 0                26.80        0.82     28.43      0.85  partly-cloudy-night
# 1                27.04        0.77     28.32      0.85  partly-cloudy-night
# 2                27.21        0.78     28.34      0.85  partly-cloudy-night
# 3                27.01        0.34     27.97      0.84  partly-cloudy-night
# 4                26.65        0.95     28.10      0.85               cloudy
#
#    precipAccumulation  precipIntensity  precipProbability precipType  \
# 0                 NaN              0.0                0.0        NaN
# 1                 NaN              0.0                0.0        NaN
# 2                 NaN              0.0                0.0        NaN
# 3                 NaN              0.0                0.0        NaN
# 4                 NaN              0.0                0.0        NaN
#
#    pressure        summary  temperature        time  visibility  windBearing  \
# 0   1009.73  Mostly Cloudy        32.48  1136091600        8.84        335.0
# 1   1010.35  Mostly Cloudy        32.33  1136095200        7.67        345.0
# 2   1011.40  Mostly Cloudy        32.29  1136098800        8.69        344.0
# 3   1012.17  Partly Cloudy        32.19  1136102400        8.79        345.0
# 4   1012.67       Overcast        32.00  1136106000        8.41        339.0
#
#    windSpeed
# 0       6.00
# 1       5.49
# 2       5.23
# 3       5.32
# 4       5.49

# %%
# # Adding datetime column to weather data

weather['datetime'] = pd.to_datetime(weather['time'], unit='s', utc=True)

# %%
# Adjusting the datetime for timezone 

tz = pytz.timezone('America/New_York')

adjustDateTime = []
for i in range(len(weather)):
    adjustDateTime.append(weather['datetime'][i].tz_localize(pytz.utc).tz_convert(tz).tz_localize(None))

# %%
# Adding the adjusted column

weather['datetime_adj'] = adjustDateTime

# %%
# Reweather.head()

# %%
# Removing duplicated rows

weather = weather.drop_duplicates(subset=['datetime_adj'])

# %% [markdown]
# ---

# %% [markdown]
# # CRIME

# %%
## Downloading the crime data -- very large, don't run again

#!wget "https://data.cityofnewyork.us/api/views/qgea-i56i/rows.csv?accessType=DOWNLOAD"

# %%
# Reading in the crime data

crimeData = pd.read_csv("rows.csv_accessType=DOWNLOAD")
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Looking through the columns

crimeData.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')

# %%
crimeData.PREM_TYP_DESC.unique()
# Out:
# array(['BAR/NIGHT CLUB', nan, 'OTHER', 'RESIDENCE-HOUSE', 'DRUG STORE',
#        'STREET', 'RESIDENCE - APT. HOUSE', 'FAST FOOD', 'RESTAURANT/DINER',
#        'DRY CLEANER/LAUNDRY', 'PUBLIC BUILDING',
#        'RESIDENCE - PUBLIC HOUSING', 'PARK/PLAYGROUND',
#        'PARKING LOT/GARAGE (PUBLIC)', 'GAS STATION', 'TUNNEL',
#        'CHAIN STORE', 'CHECK CASHING BUSINESS', 'TRANSIT - NYC SUBWAY',
#        'BUS (NYC TRANSIT)', 'BEAUTY & NAIL SALON', 'GROCERY/BODEGA',
#        'COMMERCIAL BUILDING', 'FOOD SUPERMARKET', 'HOTEL/MOTEL',
#        'SMALL MERCHANT', 'CHURCH', 'PARKING LOT/GARAGE (PRIVATE)',
#        'DEPARTMENT STORE', 'STORE UNCLASSIFIED', 'GYM/FITNESS FACILITY',
#        'VARIETY STORE', 'CLOTHING/BOUTIQUE', 'FERRY/FERRY TERMINAL',
#        'DOCTOR/DENTIST OFFICE', 'TELECOMM. STORE', 'JEWELRY',
#        'CONSTRUCTION SITE', 'BUS STOP', 'BANK', 'HOSPITAL',
#        'TAXI (LIVERY LICENSED)', 'ATM', 'BRIDGE',
#        'PRIVATE/PAROCHIAL SCHOOL', 'SOCIAL CLUB/POLICY', 'CANDY STORE',
#        'FACTORY/WAREHOUSE', 'AIRPORT TERMINAL', 'LIQUOR STORE',
#        'BOOK/CARD', 'OPEN AREAS (OPEN LOTS)', 'MARINA/PIER',
#        'HIGHWAY/PARKWAY', 'PUBLIC SCHOOL', 'BUS (OTHER)',
#        'TRANSIT FACILITY (OTHER)', 'SYNAGOGUE', 'ABANDONED BUILDING',
#        'SHOE', 'BUS TERMINAL', 'STORAGE FACILITY', 'VIDEO STORE',
#        'TAXI (YELLOW LICENSED)', 'TAXI/LIVERY (UNLICENSED)',
#        'OTHER HOUSE OF WORSHIP', 'PHOTO/COPY', 'MOSQUE', 'LOAN COMPANY',
#        'CEMETERY', 'TRAMWAY'], dtype=object)

# %%
crimeData.PREM_TYP_DESC.value_counts()
# Out:
# STREET                          1841239
# RESIDENCE - APT. HOUSE          1158315
# RESIDENCE-HOUSE                  549568
# RESIDENCE - PUBLIC HOUSING       419936
# OTHER                            148410
# COMMERCIAL BUILDING              144019
# TRANSIT - NYC SUBWAY             117859
# DEPARTMENT STORE                 107343
# CHAIN STORE                      107217
# PUBLIC SCHOOL                     71369
# PARK/PLAYGROUND                   66910
# GROCERY/BODEGA                    63868
# RESTAURANT/DINER                  62655
# BAR/NIGHT CLUB                    62573
# CLOTHING/BOUTIQUE                 46040
# DRUG STORE                        42202
# PUBLIC BUILDING                   35437
# PARKING LOT/GARAGE (PUBLIC)       32031
# PARKING LOT/GARAGE (PRIVATE)      31617
# FOOD SUPERMARKET                  29703
# HOSPITAL                          26064
# STORE UNCLASSIFIED                25614
# FAST FOOD                         25516
# SMALL MERCHANT                    23747
# BANK                              23412
# HOTEL/MOTEL                       22350
# GYM/FITNESS FACILITY              17510
# HIGHWAY/PARKWAY                   16330
# AIRPORT TERMINAL                  15869
# BEAUTY & NAIL SALON               14432
#                                  ...
# PRIVATE/PAROCHIAL SCHOOL           6750
# CHECK CASHING BUSINESS             6167
# BRIDGE                             6034
# FACTORY/WAREHOUSE                  5969
# TAXI (YELLOW LICENSED)             5441
# STORAGE FACILITY                   4981
# BUS STOP                           4805
# TAXI (LIVERY LICENSED)             4797
# ATM                                4747
# TRANSIT FACILITY (OTHER)           4704
# JEWELRY                            4133
# BUS TERMINAL                       3981
# SHOE                               3946
# LIQUOR STORE                       3730
# SOCIAL CLUB/POLICY                 3544
# TUNNEL                             2998
# BUS (OTHER)                        2823
# MARINA/PIER                        2366
# ABANDONED BUILDING                 2126
# SYNAGOGUE                          2055
# VIDEO STORE                        2020
# BOOK/CARD                          1784
# FERRY/FERRY TERMINAL               1566
# TAXI/LIVERY (UNLICENSED)            957
# OTHER HOUSE OF WORSHIP              823
# PHOTO/COPY                          780
# MOSQUE                              757
# CEMETERY                            697
# LOAN COMPANY                        404
# TRAMWAY                             106
# Name: PREM_TYP_DESC, dtype: int64

# %%
crimeData.tail()
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 5580030   582350583   01/01/2015     03:50:00   01/01/2016     04:00:00
# 5580031   258046495   01/01/2015     01:25:00   01/01/2016     01:30:00
# 5580032   640212578   01/01/2015     00:30:00   01/01/2016     00:40:00
# 5580033   496500431   06/30/2014     12:00:00   12/29/2015     12:00:00
# 5580034   256379572   12/31/2001     16:00:00   01/01/2016     10:50:00
#
#              RPT_DT  KY_CD                      OFNS_DESC  PD_CD  \
# 5580030  01/01/2016    105                        ROBBERY  399.0
# 5580031  01/01/2016    578                  HARRASSMENT 2  638.0
# 5580032  01/01/2016    106                 FELONY ASSAULT  109.0
# 5580033  01/01/2016    361  OFF. AGNST PUB ORD SENSBLTY &  639.0
# 5580034  01/01/2016    107                       BURGLARY  213.0
#
#                                  PD_DESC              ...                \
# 5580030  ROBBERY,COMMERCIAL UNCLASSIFIED              ...
# 5580031            HARASSMENT,SUBD 3,4,5              ...
# 5580032         ASSAULT 2,1,UNCLASSIFIED              ...
# 5580033          AGGRAVATED HARASSMENT 2              ...
# 5580034        BURGLARY,COMMERCIAL,NIGHT              ...
#
#         ADDR_PCT_CD LOC_OF_OCCUR_DESC           PREM_TYP_DESC PARKS_NM  \
# 5580030        30.0            INSIDE             HOTEL/MOTEL      NaN
# 5580031        41.0               NaN    TRANSIT - NYC SUBWAY      NaN
# 5580032       109.0          FRONT OF          BAR/NIGHT CLUB      NaN
# 5580033        50.0            INSIDE  RESIDENCE - APT. HOUSE      NaN
# 5580034        84.0            INSIDE           PUBLIC SCHOOL      NaN
#
#          HADEVELOPT X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 5580030         NaN   998372.0   240146.0  40.825818 -73.948975
# 5580031         NaN  1014468.0   238156.0  40.820315 -73.890825
# 5580032         NaN  1030529.0   214093.0  40.754199 -73.832963
# 5580033         NaN  1009735.0   261272.0  40.883777 -73.907837
# 5580034         NaN   989682.0   188334.0  40.683617 -73.980416
#
#                                Lat_Lon
# 5580030  (40.825817778, -73.948974825)
# 5580031  (40.820315396, -73.890824603)
# 5580032  (40.754199468, -73.832962523)
# 5580033  (40.883776851, -73.907836928)
# 5580034  (40.683616638, -73.980416007)
#
# [5 rows x 24 columns]

# %%
# Filtering down to complaint dates between 01/01/2006 - 12/31/2017

crimeData['year'] = crimeData['CMPLNT_FR_DT'].str[-4:].fillna(0).astype(int)
crimeData['hour'] = crimeData['CMPLNT_FR_TM'].str[:2].fillna(0).astype(int)
crime = crimeData[((crimeData['year'] > 2005) & (crimeData['hour'] < 24))]

# Creating datetime column

crime['datetime'] = pd.to_datetime((crime['CMPLNT_FR_DT'] + ' ' + crime['CMPLNT_FR_TM']), format='%m/%d/%Y %H:%M:%S')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# dropping NaNs from datetime

crime = crime.dropna(axis=0, subset=['datetime'])
crime = crime.reset_index()

# %%
# Rounding to the nearest hour

def hour_rounder(t):
    # Rounds to nearest hour by adding a timedelta hour if minute >= 30
    return (t.replace(second=0, microsecond=0, minute=0, hour=t.hour)
               +timedelta(hours=t.minute//30))

crimeRound = []

for i in range(len(crime)):
     t = crime['datetime'][i]
     crimeRound.append(hour_rounder(t))

# %%
# Adding the rounded datetime to the dataframe

crime['datetime_round'] = crimeRound

# %%
crime.head()
# Out:
#    index  CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0      0   101109527   12/31/2015     23:45:00          NaN          NaN
# 1      1   153401121   12/31/2015     23:36:00          NaN          NaN
# 2      2   569369778   12/31/2015     23:30:00          NaN          NaN
# 3      3   968417082   12/31/2015     23:30:00          NaN          NaN
# 4      4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00
#
#        RPT_DT  KY_CD                        OFNS_DESC  PD_CD  \
# 0  12/31/2015    113                          FORGERY  729.0
# 1  12/31/2015    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2  12/31/2015    117                  DANGEROUS DRUGS  503.0
# 3  12/31/2015    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4  12/31/2015    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#           ...         HADEVELOPT X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0         ...                NaN  1007314.0   241257.0  40.828848 -73.916661
# 1         ...                NaN  1043991.0   193406.0  40.697338 -73.784557
# 2         ...                NaN   999463.0   231690.0  40.802607 -73.945052
# 3         ...                NaN  1060183.0   177862.0  40.654549 -73.726339
# 4         ...                NaN   987606.0   208148.0  40.738002 -73.987891
#
#                          Lat_Lon  year hour            datetime  \
# 0  (40.828848333, -73.916661142)  2015   23 2015-12-31 23:45:00
# 1  (40.697338138, -73.784556739)  2015   23 2015-12-31 23:36:00
# 2  (40.802606608, -73.945051911)  2015   23 2015-12-31 23:30:00
# 3  (40.654549444, -73.726338791)  2015   23 2015-12-31 23:30:00
# 4     (40.7380024, -73.98789129)  2015   23 2015-12-31 23:25:00
#
#        datetime_round
# 0 2016-01-01 00:00:00
# 1 2016-01-01 00:00:00
# 2 2016-01-01 00:00:00
# 3 2016-01-01 00:00:00
# 4 2015-12-31 23:00:00
#
# [5 rows x 29 columns]

# %%
# Unique crime types

crimeData.OFNS_DESC.unique()
# Out:
# array(['FORGERY', 'MURDER & NON-NEGL. MANSLAUGHTER', 'DANGEROUS DRUGS',
#        'ASSAULT 3 & RELATED OFFENSES', 'FELONY ASSAULT',
#        'DANGEROUS WEAPONS', 'PETIT LARCENY', 'GRAND LARCENY', 'ROBBERY',
#        'OFFENSES AGAINST PUBLIC ADMINI', 'CRIMINAL MISCHIEF & RELATED OF',
#        'RAPE', 'INTOXICATED & IMPAIRED DRIVING', 'HARRASSMENT 2',
#        'SEX CRIMES', 'BURGLARY', 'CRIMINAL TRESPASS',
#        'MISCELLANEOUS PENAL LAW', 'VEHICLE AND TRAFFIC LAWS',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'FRAUDS',
#        'GRAND LARCENY OF MOTOR VEHICLE', 'OFFENSES INVOLVING FRAUD',
#        'OFFENSES AGAINST THE PERSON', 'FRAUDULENT ACCOSTING',
#        'OTHER OFFENSES RELATED TO THEF', 'GAMBLING', 'ARSON',
#        'POSSESSION OF STOLEN PROPERTY', 'UNAUTHORIZED USE OF A VEHICLE',
#        'THEFT-FRAUD', 'DISORDERLY CONDUCT', nan, 'ADMINISTRATIVE CODE',
#        'CHILD ABANDONMENT/NON SUPPORT', 'OTHER STATE LAWS (NON PENAL LA',
#        'NYS LAWS-UNCLASSIFIED FELONY', "BURGLAR'S TOOLS",
#        'THEFT OF SERVICES', 'PETIT LARCENY OF MOTOR VEHICLE',
#        'ALCOHOLIC BEVERAGE CONTROL LAW',
#        'AGRICULTURE & MRKTS LAW-UNCLASSIFIED', 'ENDAN WELFARE INCOMP',
#        'KIDNAPPING & RELATED OFFENSES', 'DISRUPTION OF A RELIGIOUS SERV',
#        'PROSTITUTION & RELATED OFFENSES', 'JOSTLING',
#        'ANTICIPATORY OFFENSES', 'NYS LAWS-UNCLASSIFIED VIOLATION',
#        'HOMICIDE-NEGLIGENT-VEHICLE', 'OFFENSES AGAINST PUBLIC SAFETY',
#        'OTHER STATE LAWS', 'ESCAPE 3', 'OFFENSES RELATED TO CHILDREN',
#        'UNLAWFUL POSS. WEAP. ON SCHOOL', 'ADMINISTRATIVE CODES',
#        'NEW YORK CITY HEALTH CODE', 'LOITERING/GAMBLING (CARDS, DIC',
#        'ABORTION', 'KIDNAPPING AND RELATED OFFENSES', 'LOITERING',
#        'OTHER STATE LAWS (NON PENAL LAW)', 'INTOXICATED/IMPAIRED DRIVING',
#        'FORTUNE TELLING', 'KIDNAPPING', 'UNDER THE INFLUENCE OF DRUGS',
#        'OTHER TRAFFIC INFRACTION', 'HOMICIDE-NEGLIGENT,UNCLASSIFIE',
#        'LOITERING FOR DRUG PURPOSES', 'OFFENSES AGAINST MARRIAGE UNCL',
#        'LOITERING/DEVIATE SEX'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# # Merging the Data

# %%
df = crime.merge(weather, how='left', left_on="datetime_round", right_on="datetime_adj")

# %%
# Confirming that the new dataframe is the same length as the crime dataframe

print("left merge:", len(df) - len(crime))
# Out:
# left merge: 0

# %%
df.columns
# Out:
# Index(['index', 'CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon', 'year', 'hour', 'datetime_x', 'datetime_round',
#        'apparentTemperature', 'cloudCover', 'dewPoint', 'humidity', 'icon',
#        'precipAccumulation', 'precipIntensity', 'precipProbability',
#        'precipType', 'pressure', 'summary', 'temperature', 'time',
#        'visibility', 'windBearing', 'windSpeed', 'datetime_y', 'datetime_adj'],
#       dtype='object')

# %%
df = df.round({'dewPoint':0, 'apparentTemperature':0, 'temperature': 0, 'visibility': 1, 
               'windBearing': 0, 'windSpeed': 0, 'pressure':0, 'precipAccumulation':2 })

# %%
# Reducing df to the 7 major felony types

sevenFelonies = ['ROBBERY', 'FELONY ASSAULT', 'MURDER & NON-NEGL. MANSLAUGHTER', 'GRAND LARCENY', 'BURGLARY',
                 'GRAND LARCENY OF MOTOR VEHICLE', 'RAPE']
dfSeven = df.loc[df['OFNS_DESC'].isin(sevenFelonies)].reset_index()

# %% [markdown]
# # Plotting the data

# %%
dfSeven.groupby('temperature').size().plot();

# %%
dfSeven['temperature'].min()
# Out:
# 0.0

# %%
dfCrimesByTemp = dfSeven.groupby('temperature').size()
dfCrimesByTemp = pd.DataFrame(dfCrimesByTemp).reset_index()
dfCrimesByTemp.columns = ['Temperature', 'Count_crime']
dfCrimesByTemp.head()
# Out:
#    Temperature  Count_crime
# 0          0.0            4
# 1          1.0            3
# 2          2.0           23
# 3          3.0           12
# 4          4.0           86

# %%
dfTempNorm = dfSeven.groupby(['temperature','datetime_adj']).size()
dfTempNorm = pd.DataFrame(dfTempNorm).reset_index()
dfTempByHour = dfTempNorm.groupby('temperature').size()
dfTempByHour = pd.DataFrame(dfTempByHour).reset_index()
dfTempByHour.columns = ['Temperature', 'Count_hour']
dfTempByHour.head()
# Out:
#    Temperature  Count_hour
# 0          0.0           1
# 1          1.0           1
# 2          2.0           4
# 3          3.0           3
# 4          4.0          12

# %%
dfTempNormalized = pd.merge(dfTempByHour, dfCrimesByTemp, on='Temperature')

# %%
dfTempNormalized['avgCrimePerHour'] = dfTempNormalized.Count_crime / dfTempNormalized.Count_hour

# %%
dfTempNormalized.plot('Temperature', 'avgCrimePerHour')

# %%
tempMod = smf.ols("avgCrimePerHour ~ Temperature", data=dfTempNormalized)
tempFit = tempMod.fit()
tempFit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        avgCrimePerHour   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     630.0
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           3.32e-45
# Time:                        16:15:42   Log-Likelihood:                -164.10
# No. Observations:                 103   AIC:                             332.2
# Df Residuals:                     101   BIC:                             337.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       6.9062      0.235     29.367      0.000         6.440     7.373
# Temperature     0.1000      0.004     25.099      0.000         0.092     0.108
# ==============================================================================
# Omnibus:                       33.966   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.103
# Skew:                          -1.177   Prob(JB):                     7.39e-20
# Kurtosis:                       6.872   Cond. No.                         117.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
dfTempNormalized.plot('Temperature', 'avgCrimePerHour')
tempFitLine = tempFit.fittedvalues
pl.plot(tempFitLine);

# %%
# Defining our function

def weatherCorrelation (dataframe, crime, weatherType):
    
    """Does all of the above, but allows us to specify the specific crime type and weather type"""
    
    # Reducing dataframe based on selected crime type (listing no crime yields all results
    if crime == 'ALL CRIME':
        dataframe = dataframe
    else:
        dataframe = dataframe.loc[dataframe['OFNS_DESC'] == crime]
    
    ### NEW CODE
    
    # Removing weather outliers - first and last fifth
    
    #outCount = ((dataframe[weatherType].max() - dataframe[weatherType].min()) / 5)
    #weatherMin = dataframe[weatherType].min() + outCount
    #weatherMax = dataframe[weatherType].max() - outCount
    
    #dataframe = dataframe[(dataframe[weatherType] >= weatherMin) & (dataframe[weatherType] <= weatherMax)]
    
    ### END OF NEW CODE
    
    # Reducing crime type by weather event
    
    dfCrimesByWeather = dataframe.groupby(weatherType).size()
    dfCrimesByWeather = pd.DataFrame(dfCrimesByWeather).reset_index()
    dfCrimesByWeather.columns = [weatherType, 'Count_crime']
    
    # Calculating number of hours of each weather pattern
    
    dfWeatherNorm = dataframe.groupby([weatherType,'datetime_adj']).size()
    dfWeatherNorm = pd.DataFrame(dfWeatherNorm).reset_index()
    dfWeatherByHour = dfWeatherNorm.groupby(weatherType).size()
    dfWeatherByHour = pd.DataFrame(dfWeatherByHour).reset_index()
    dfWeatherByHour.columns = [weatherType, 'Count_hour']

    # Getting average Crime per Hour
    
    dfWeatherNormalized = pd.merge(dfCrimesByWeather, dfWeatherByHour, on=weatherType)
    dfWeatherNormalized['CrimePerHour'] = dfWeatherNormalized.Count_crime / dfWeatherNormalized.Count_hour
    
    # Fit a regression model
    
    weatherMod = smf.ols("CrimePerHour ~ " + weatherType, data=dfWeatherNormalized)
    weatherFit = weatherMod.fit()
    weatherFitLine = weatherFit.fittedvalues
    
    x = weatherFit.summary()
    y = dfWeatherNormalized.plot(weatherType, 'CrimePerHour', title=crime, legend=False)
    z = pl.plot(weatherFitLine);
    
    print("\n\n" + crime + " Regression Results:\n\n\n", x)
    return y, z

# %% [markdown]
# # Using the formula for different weather types

# %%
felonyTypes = ['ALL CRIME', 'ROBBERY', 'FELONY ASSAULT', 'MURDER & NON-NEGL. MANSLAUGHTER', 'GRAND LARCENY', 'BURGLARY',
                 'GRAND LARCENY OF MOTOR VEHICLE', 'RAPE']

weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'temperature')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     630.0
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           3.32e-45
# Time:                        16:15:49   Log-Likelihood:                -164.10
# No. Observations:                 103   AIC:                             332.2
# Df Residuals:                     101   BIC:                             337.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       6.9062      0.235     29.367      0.000         6.440     7.373
# temperature     0.1000      0.004     25.099      0.000         0.092     0.108
# ==============================================================================
# Omnibus:                       33.966   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.103
# Skew:                          -1.177   Prob(JB):                     7.39e-20
# Kurtosis:                       6.872   Cond. No.                         117.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     31.58
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.76e-07
# Time:                        16:15:49   Log-Likelihood:                -47.522
# No. Observations:                 101   AIC:                             99.04
# Df Residuals:                      99   BIC:                             104.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       2.0935      0.079     26.346      0.000         1.936     2.251
# temperature     0.0075      0.001      5.620      0.000         0.005     0.010
# ==============================================================================
# Omnibus:                       47.670   Durbin-Watson:                   1.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.246
# Skew:                          -1.599   Prob(JB):                     3.56e-36
# Kurtosis:                       8.345   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     107.8
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.45e-17
# Time:                        16:15:50   Log-Likelihood:                -23.146
# No. Observations:                 102   AIC:                             50.29
# Df Residuals:                     100   BIC:                             55.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.9622      0.061     32.077      0.000         1.841     2.084
# temperature     0.0107      0.001     10.381      0.000         0.009     0.013
# ==============================================================================
# Omnibus:                       36.497   Durbin-Watson:                   2.500
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.687
# Skew:                          -0.671   Prob(JB):                     2.63e-82
# Kurtosis:                      12.306   Cond. No.                         120.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6757
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.413
# Time:                        16:15:50   Log-Likelihood:                 90.117
# No. Observations:                  87   AIC:                            -176.2
# Df Residuals:                      85   BIC:                            -171.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.0574      0.021     50.154      0.000         1.015     1.099
# temperature     0.0003      0.000      0.822      0.413        -0.000     0.001
# ==============================================================================
# Omnibus:                       84.539   Durbin-Watson:                   2.516
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              702.607
# Skew:                           3.140   Prob(JB):                    2.70e-153
# Kurtosis:                      15.426   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     377.1
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.05e-35
# Time:                        16:15:50   Log-Likelihood:                -97.397
# No. Observations:                 102   AIC:                             198.8
# Df Residuals:                     100   BIC:                             204.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       3.0067      0.127     23.749      0.000         2.756     3.258
# temperature     0.0414      0.002     19.418      0.000         0.037     0.046
# ==============================================================================
# Omnibus:                       12.864   Durbin-Watson:                   1.073
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               37.167
# Skew:                           0.218   Prob(JB):                     8.50e-09
# Kurtosis:                       5.925   Cond. No.                         119.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# BURGLARY Regression Results:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     89.55
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.62e-15
# Time:                        16:15:51   Log-Likelihood:                -17.243
# No. Observations:                 101   AIC:                             38.49
# Df Residuals:                      99   BIC:                             43.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       2.0875      0.059     35.432      0.000         1.971     2.204
# temperature     0.0094      0.001      9.463      0.000         0.007     0.011
# ==============================================================================
# Omnibus:                       38.771   Durbin-Watson:                   1.295
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              230.140
# Skew:                           1.008   Prob(JB):                     1.06e-50
# Kurtosis:                      10.115   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     49.47
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           2.74e-10
# Time:                        16:15:51   Log-Likelihood:                 23.531
# No. Observations:                 100   AIC:                            -43.06
# Df Residuals:                      98   BIC:                            -37.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.5175      0.039     38.433      0.000         1.439     1.596
# temperature     0.0047      0.001      7.034      0.000         0.003     0.006
# ==============================================================================
# Omnibus:                       52.202   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.026
# Skew:                          -1.539   Prob(JB):                     7.08e-66
# Kurtosis:                      10.908   Cond. No.                         121.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.1119
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.739
# Time:                        16:15:51   Log-Likelihood:                 72.455
# No. Observations:                  96   AIC:                            -140.9
# Df Residuals:                      94   BIC:                            -135.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.1457      0.025     45.737      0.000         1.096     1.195
# temperature    -0.0001      0.000     -0.335      0.739        -0.001     0.001
# ==============================================================================
# Omnibus:                       82.589   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              775.923
# Skew:                           2.680   Prob(JB):                    3.24e-169
# Kurtosis:                      15.855   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'apparentTemperature')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     611.3
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           5.53e-51
# Time:                        16:15:53   Log-Likelihood:                -232.13
# No. Observations:                 132   AIC:                             468.3
# Df Residuals:                     130   BIC:                             474.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               8.5204      0.192     44.412      0.000         8.141     8.900
# apparentTemperature     0.0799      0.003     24.724      0.000         0.074     0.086
# ==============================================================================
# Omnibus:                       94.033   Durbin-Watson:                   1.280
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1244.260
# Skew:                           2.184   Prob(JB):                    6.49e-271
# Kurtosis:                      17.393   Cond. No.                         92.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     55.07
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.47e-11
# Time:                        16:15:53   Log-Likelihood:                -63.005
# No. Observations:                 129   AIC:                             130.0
# Df Residuals:                     127   BIC:                             135.7
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               2.1469      0.056     38.209      0.000         2.036     2.258
# apparentTemperature     0.0070      0.001      7.421      0.000         0.005     0.009
# ==============================================================================
# Omnibus:                       22.581   Durbin-Watson:                   1.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.708
# Skew:                          -0.666   Prob(JB):                     2.18e-12
# Kurtosis:                       5.867   Cond. No.                         96.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     80.97
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           2.39e-15
# Time:                        16:15:54   Log-Likelihood:                -89.303
# No. Observations:                 132   AIC:                             182.6
# Df Residuals:                     130   BIC:                             188.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               2.0861      0.065     32.084      0.000         1.957     2.215
# apparentTemperature     0.0099      0.001      8.998      0.000         0.008     0.012
# ==============================================================================
# Omnibus:                      158.952   Durbin-Watson:                   1.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6287.465
# Skew:                           4.261   Prob(JB):                         0.00
# Kurtosis:                      35.720   Cond. No.                         92.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     2.537
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.114
# Time:                        16:15:54   Log-Likelihood:                 81.833
# No. Observations:                 105   AIC:                            -159.7
# Df Residuals:                     103   BIC:                            -154.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               1.0449      0.020     51.933      0.000         1.005     1.085
# apparentTemperature     0.0006      0.000      1.593      0.114        -0.000     0.001
# ==============================================================================
# Omnibus:                      155.307   Durbin-Watson:                   1.382
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7078.519
# Skew:                           5.403   Prob(JB):                         0.00
# Kurtosis:                      41.745   Cond. No.                         105.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.597
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     191.4
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           2.95e-27
# Time:                        16:15:54   Log-Likelihood:                -183.87
# No. Observations:                 131   AIC:                             371.7
# Df Residuals:                     129   BIC:                             377.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               3.7621      0.137     27.553      0.000         3.492     4.032
# apparentTemperature     0.0317      0.002     13.835      0.000         0.027     0.036
# ==============================================================================
# Omnibus:                       96.096   Durbin-Watson:                   1.658
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1138.090
# Skew:                           2.326   Prob(JB):                    7.36e-248
# Kurtosis:                      16.670   Cond. No.                         93.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.456
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     108.3
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           8.66e-19
# Time:                        16:15:55   Log-Likelihood:                -36.222
# No. Observations:                 131   AIC:                             76.44
# Df Residuals:                     129   BIC:                             82.19
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               2.1825      0.044     49.470      0.000         2.095     2.270
# apparentTemperature     0.0077      0.001     10.407      0.000         0.006     0.009
# ==============================================================================
# Omnibus:                       38.249   Durbin-Watson:                   1.336
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              348.472
# Skew:                           0.599   Prob(JB):                     2.14e-76
# Kurtosis:                      10.900   Cond. No.                         93.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     86.71
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           5.17e-16
# Time:                        16:15:55   Log-Likelihood:                 19.294
# No. Observations:                 128   AIC:                            -34.59
# Df Residuals:                     126   BIC:                            -28.88
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               1.5618      0.030     51.839      0.000         1.502     1.621
# apparentTemperature     0.0047      0.001      9.312      0.000         0.004     0.006
# ==============================================================================
# Omnibus:                       91.824   Durbin-Watson:                   2.303
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1839.444
# Skew:                           1.996   Prob(JB):                         0.00
# Kurtosis:                      21.137   Cond. No.                         97.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                   0.03307
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.856
# Time:                        16:15:55   Log-Likelihood:                 41.613
# No. Observations:                 122   AIC:                            -79.23
# Df Residuals:                     120   BIC:                            -73.62
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               1.1421      0.027     41.771      0.000         1.088     1.196
# apparentTemperature -8.074e-05      0.000     -0.182      0.856        -0.001     0.001
# ==============================================================================
# Omnibus:                      135.548   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2486.745
# Skew:                           3.991   Prob(JB):                         0.00
# Kurtosis:                      23.627   Cond. No.                         107.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'dewPoint')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     354.3
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.20e-33
# Time:                        16:15:56   Log-Likelihood:                -109.04
# No. Observations:                  96   AIC:                             222.1
# Df Residuals:                      94   BIC:                             227.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     10.3307      0.116     89.391      0.000        10.101    10.560
# dewPoint       0.0528      0.003     18.822      0.000         0.047     0.058
# ==============================================================================
# Omnibus:                       67.696   Durbin-Watson:                   0.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              357.830
# Skew:                          -2.309   Prob(JB):                     1.99e-78
# Kurtosis:                      11.255   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     121.0
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.39e-18
# Time:                        16:15:56   Log-Likelihood:                 14.564
# No. Observations:                  96   AIC:                            -25.13
# Df Residuals:                      94   BIC:                            -20.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.2966      0.032     72.018      0.000         2.233     2.360
# dewPoint       0.0085      0.001     11.002      0.000         0.007     0.010
# ==============================================================================
# Omnibus:                       61.830   Durbin-Watson:                   1.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              249.455
# Skew:                          -2.202   Prob(JB):                     6.79e-55
# Kurtosis:                       9.555   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     311.7
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.32e-31
# Time:                        16:15:56   Log-Likelihood:                 43.047
# No. Observations:                  96   AIC:                            -82.09
# Df Residuals:                      94   BIC:                            -76.96
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.2062      0.024     93.080      0.000         2.159     2.253
# dewPoint       0.0102      0.001     17.656      0.000         0.009     0.011
# ==============================================================================
# Omnibus:                       35.514   Durbin-Watson:                   1.457
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              162.590
# Skew:                          -1.039   Prob(JB):                     4.94e-36
# Kurtosis:                       9.028   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.661
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.201
# Time:                        16:15:57   Log-Likelihood:                 110.41
# No. Observations:                  90   AIC:                            -216.8
# Df Residuals:                      88   BIC:                            -211.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.0596      0.012     86.359      0.000         1.035     1.084
# dewPoint       0.0004      0.000      1.289      0.201        -0.000     0.001
# ==============================================================================
# Omnibus:                       46.524   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.226
# Skew:                           1.915   Prob(JB):                     9.53e-26
# Kurtosis:                       7.007   Cond. No.                         68.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     68.70
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           7.89e-13
# Time:                        16:15:57   Log-Likelihood:                -47.676
# No. Observations:                  96   AIC:                             99.35
# Df Residuals:                      94   BIC:                             104.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      4.6500      0.061     76.250      0.000         4.529     4.771
# dewPoint       0.0123      0.001      8.289      0.000         0.009     0.015
# ==============================================================================
# Omnibus:                       56.723   Durbin-Watson:                   1.708
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              248.156
# Skew:                          -1.921   Prob(JB):                     1.30e-54
# Kurtosis:                       9.876   Cond. No.                         61.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     70.78
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           4.62e-13
# Time:                        16:15:57   Log-Likelihood:                 20.462
# No. Observations:                  95   AIC:                            -36.92
# Df Residuals:                      93   BIC:                            -31.82
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.3055      0.030     76.893      0.000         2.246     2.365
# dewPoint       0.0062      0.001      8.413      0.000         0.005     0.008
# ==============================================================================
# Omnibus:                       50.805   Durbin-Watson:                   1.177
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.372
# Skew:                          -1.795   Prob(JB):                     6.80e-40
# Kurtosis:                       8.717   Cond. No.                         60.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     50.26
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           2.57e-10
# Time:                        16:15:57   Log-Likelihood:                 34.686
# No. Observations:                  95   AIC:                            -65.37
# Df Residuals:                      93   BIC:                            -60.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.6300      0.026     62.080      0.000         1.578     1.682
# dewPoint       0.0045      0.001      7.090      0.000         0.003     0.006
# ==============================================================================
# Omnibus:                       91.845   Durbin-Watson:                   1.259
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              895.301
# Skew:                          -3.159   Prob(JB):                    3.87e-195
# Kurtosis:                      16.648   Cond. No.                         62.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.173
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.282
# Time:                        16:15:58   Log-Likelihood:                 56.825
# No. Observations:                  92   AIC:                            -109.6
# Df Residuals:                      90   BIC:                            -104.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.1277      0.021     52.917      0.000         1.085     1.170
# dewPoint       0.0006      0.001      1.083      0.282        -0.000     0.002
# ==============================================================================
# Omnibus:                      106.518   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1821.945
# Skew:                           3.736   Prob(JB):                         0.00
# Kurtosis:                      23.481   Cond. No.                         63.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'visibility')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.349
# Method:                 Least Squares   F-statistic:                     54.07
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           5.92e-11
# Time:                        16:15:58   Log-Likelihood:                -116.23
# No. Observations:                 100   AIC:                             236.5
# Df Residuals:                      98   BIC:                             241.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     10.9887      0.157     69.782      0.000        10.676    11.301
# visibility     0.1991      0.027      7.353      0.000         0.145     0.253
# ==============================================================================
# Omnibus:                       20.614   Durbin-Watson:                   0.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.140
# Skew:                          -0.948   Prob(JB):                     2.85e-07
# Kurtosis:                       4.908   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     12.15
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           0.000737
# Time:                        16:15:59   Log-Likelihood:                 34.374
# No. Observations:                 100   AIC:                            -64.75
# Df Residuals:                      98   BIC:                            -59.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.5128      0.035     71.945      0.000         2.443     2.582
# visibility     0.0209      0.006      3.485      0.001         0.009     0.033
# ==============================================================================
# Omnibus:                        5.017   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.081   Jarque-Bera (JB):                7.102
# Skew:                           0.027   Prob(JB):                       0.0287
# Kurtosis:                       4.304   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     89.83
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.65e-15
# Time:                        16:15:59   Log-Likelihood:                 39.569
# No. Observations:                 100   AIC:                            -75.14
# Df Residuals:                      98   BIC:                            -69.93
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.2040      0.033     66.467      0.000         2.138     2.270
# visibility     0.0540      0.006      9.478      0.000         0.043     0.065
# ==============================================================================
# Omnibus:                       44.259   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.278
# Skew:                          -1.414   Prob(JB):                     6.42e-38
# Kurtosis:                       8.754   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.7473
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.389
# Time:                        16:15:59   Log-Likelihood:                 90.834
# No. Observations:                  98   AIC:                            -177.7
# Df Residuals:                      96   BIC:                            -172.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.0919      0.020     53.849      0.000         1.052     1.132
# visibility    -0.0030      0.003     -0.864      0.389        -0.010     0.004
# ==============================================================================
# Omnibus:                       43.195   Durbin-Watson:                   2.210
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.598
# Skew:                           1.671   Prob(JB):                     8.67e-23
# Kurtosis:                       6.702   Cond. No.                         12.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     32.88
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.09e-07
# Time:                        16:15:59   Log-Likelihood:                -37.094
# No. Observations:                 100   AIC:                             78.19
# Df Residuals:                      98   BIC:                             83.40
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      4.5736      0.071     64.079      0.000         4.432     4.715
# visibility     0.0704      0.012      5.734      0.000         0.046     0.095
# ==============================================================================
# Omnibus:                       22.404   Durbin-Watson:                   1.278
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.229
# Skew:                          -0.867   Prob(JB):                     2.49e-10
# Kurtosis:                       5.758   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                 0.0005440
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.981
# Time:                        16:16:00   Log-Likelihood:                 26.687
# No. Observations:                 100   AIC:                            -49.37
# Df Residuals:                      98   BIC:                            -44.16
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.6299      0.038     69.727      0.000         2.555     2.705
# visibility     0.0002      0.006      0.023      0.981        -0.013     0.013
# ==============================================================================
# Omnibus:                        4.362   Durbin-Watson:                   1.416
# Prob(Omnibus):                  0.113   Jarque-Bera (JB):                4.594
# Skew:                          -0.227   Prob(JB):                        0.101
# Kurtosis:                       3.947   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     6.473
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0125
# Time:                        16:16:00   Log-Likelihood:                 68.613
# No. Observations:                 100   AIC:                            -133.2
# Df Residuals:                      98   BIC:                            -128.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.7543      0.025     70.738      0.000         1.705     1.804
# visibility     0.0108      0.004      2.544      0.013         0.002     0.019
# ==============================================================================
# Omnibus:                        5.141   Durbin-Watson:                   1.381
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.556
# Skew:                          -0.420   Prob(JB):                        0.102
# Kurtosis:                       3.623   Cond. No.                         12.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     3.317
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0716
# Time:                        16:16:00   Log-Likelihood:                 34.662
# No. Observations:                  99   AIC:                            -65.32
# Df Residuals:                      97   BIC:                            -60.13
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.0902      0.035     30.804      0.000         1.020     1.160
# visibility     0.0110      0.006      1.821      0.072        -0.001     0.023
# ==============================================================================
# Omnibus:                      125.073   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2599.344
# Skew:                           4.378   Prob(JB):                         0.00
# Kurtosis:                      26.526   Cond. No.                         12.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'precipIntensity')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     6.041
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0141
# Time:                        16:16:01   Log-Likelihood:                -4743.0
# No. Observations:                1653   AIC:                             9490.
# Df Residuals:                    1651   BIC:                             9501.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept          12.0213      0.151     79.418      0.000        11.724    12.318
# precipIntensity     2.3819      0.969      2.458      0.014         0.481     4.283
# ==============================================================================
# Omnibus:                       75.260   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.672
# Skew:                           0.304   Prob(JB):                     4.27e-34
# Kurtosis:                       4.365   Cond. No.                         9.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.001926
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.965
# Time:                        16:16:01   Log-Likelihood:                -2477.1
# No. Observations:                1552   AIC:                             4958.
# Df Residuals:                    1550   BIC:                             4969.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           2.5729      0.043     59.218      0.000         2.488     2.658
# precipIntensity     0.0128      0.292      0.044      0.965        -0.560     0.585
# ==============================================================================
# Omnibus:                      414.512   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1319.464
# Skew:                           1.321   Prob(JB):                    3.03e-287
# Kurtosis:                       6.664   Cond. No.                         9.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.09462
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.758
# Time:                        16:16:01   Log-Likelihood:                -2360.1
# No. Observations:                1501   AIC:                             4724.
# Df Residuals:                    1499   BIC:                             4735.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           2.4304      0.043     56.443      0.000         2.346     2.515
# precipIntensity     0.0895      0.291      0.308      0.758        -0.481     0.660
# ==============================================================================
# Omnibus:                      518.963   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2335.526
# Skew:                           1.588   Prob(JB):                         0.00
# Kurtosis:                       8.221   Cond. No.                         9.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.03621
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.849
# Time:                        16:16:02   Log-Likelihood:                -27.917
# No. Observations:                 313   AIC:                             59.83
# Df Residuals:                     311   BIC:                             67.33
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           1.0830      0.019     56.041      0.000         1.045     1.121
# precipIntensity    -0.0489      0.257     -0.190      0.849        -0.555     0.457
# ==============================================================================
# Omnibus:                      266.236   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3398.898
# Skew:                           3.686   Prob(JB):                         0.00
# Kurtosis:                      17.363   Cond. No.                         17.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.569
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0590
# Time:                        16:16:02   Log-Likelihood:                -3665.2
# No. Observations:                1608   AIC:                             7334.
# Df Residuals:                    1606   BIC:                             7345.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           4.9745      0.085     58.682      0.000         4.808     5.141
# precipIntensity     1.0454      0.553      1.889      0.059        -0.040     2.131
# ==============================================================================
# Omnibus:                      522.663   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3125.731
# Skew:                           1.386   Prob(JB):                         0.00
# Kurtosis:                       9.242   Cond. No.                         9.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                 0.0003791
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.984
# Time:                        16:16:02   Log-Likelihood:                -2540.7
# No. Observations:                1558   AIC:                             5085.
# Df Residuals:                    1556   BIC:                             5096.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           2.5770      0.045     57.452      0.000         2.489     2.665
# precipIntensity    -0.0058      0.299     -0.019      0.984        -0.592     0.581
# ==============================================================================
# Omnibus:                      499.602   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1924.364
# Skew:                           1.521   Prob(JB):                         0.00
# Kurtosis:                       7.515   Cond. No.                         9.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     15.52
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           8.55e-05
# Time:                        16:16:03   Log-Likelihood:                -1783.5
# No. Observations:                1383   AIC:                             3571.
# Df Residuals:                    1381   BIC:                             3581.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           1.8162      0.033     54.375      0.000         1.751     1.882
# precipIntensity     0.9332      0.237      3.940      0.000         0.469     1.398
# ==============================================================================
# Omnibus:                      444.425   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1645.246
# Skew:                           1.535   Prob(JB):                         0.00
# Kurtosis:                       7.374   Cond. No.                         10.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1583
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.691
# Time:                        16:16:03   Log-Likelihood:                -538.62
# No. Observations:                 623   AIC:                             1081.
# Df Residuals:                     621   BIC:                             1090.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           1.1599      0.030     38.780      0.000         1.101     1.219
# precipIntensity    -0.1135      0.285     -0.398      0.691        -0.674     0.447
# ==============================================================================
# Omnibus:                      913.561   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           196880.528
# Skew:                           8.119   Prob(JB):                         0.00
# Kurtosis:                      88.562   Cond. No.                         12.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'windBearing')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1578
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.691
# Time:                        16:16:04   Log-Likelihood:                -496.78
# No. Observations:                 360   AIC:                             997.6
# Df Residuals:                     358   BIC:                             1005.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept      12.6929      0.101    125.117      0.000        12.493    12.892
# windBearing     0.0002      0.000      0.397      0.691        -0.001     0.001
# ==============================================================================
# Omnibus:                       15.894   Durbin-Watson:                   0.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.747
# Skew:                           0.371   Prob(JB):                      0.00171
# Kurtosis:                       2.453   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     12.23
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           0.000530
# Time:                        16:16:04   Log-Likelihood:                 144.37
# No. Observations:                 360   AIC:                            -284.7
# Df Residuals:                     358   BIC:                            -277.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       2.6483      0.017    154.950      0.000         2.615     2.682
# windBearing     0.0003   8.24e-05      3.497      0.001         0.000     0.000
# ==============================================================================
# Omnibus:                        9.282   Durbin-Watson:                   1.204
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               10.143
# Skew:                           0.301   Prob(JB):                      0.00627
# Kurtosis:                       3.559   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     10.84
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):            0.00109
# Time:                        16:16:04   Log-Likelihood:                 67.873
# No. Observations:                 360   AIC:                            -131.7
# Df Residuals:                     358   BIC:                            -124.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       2.5779      0.021    121.956      0.000         2.536     2.619
# windBearing     0.0003      0.000      3.292      0.001         0.000     0.001
# ==============================================================================
# Omnibus:                       13.465   Durbin-Watson:                   0.890
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               10.603
# Skew:                           0.326   Prob(JB):                      0.00498
# Kurtosis:                       2.470   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.514
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.219
# Time:                        16:16:04   Log-Likelihood:                 352.72
# No. Observations:                 359   AIC:                            -701.4
# Df Residuals:                     357   BIC:                            -693.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.0839      0.010    113.176      0.000         1.065     1.103
# windBearing -5.675e-05   4.61e-05     -1.230      0.219        -0.000   3.4e-05
# ==============================================================================
# Omnibus:                      129.465   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.945
# Skew:                           1.664   Prob(JB):                     6.38e-87
# Kurtosis:                       6.932   Cond. No.                         415.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9326
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.335
# Time:                        16:16:05   Log-Likelihood:                -203.15
# No. Observations:                 360   AIC:                             410.3
# Df Residuals:                     358   BIC:                             418.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       5.2972      0.045    118.038      0.000         5.209     5.385
# windBearing    -0.0002      0.000     -0.966      0.335        -0.001     0.000
# ==============================================================================
# Omnibus:                        3.303   Durbin-Watson:                   0.546
# Prob(Omnibus):                  0.192   Jarque-Bera (JB):                3.087
# Skew:                           0.221   Prob(JB):                        0.214
# Kurtosis:                       3.098   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     23.80
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.61e-06
# Time:                        16:16:05   Log-Likelihood:                 213.15
# No. Observations:                 360   AIC:                            -422.3
# Df Residuals:                     358   BIC:                            -414.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       2.6462      0.014    187.418      0.000         2.618     2.674
# windBearing    -0.0003   6.81e-05     -4.879      0.000        -0.000    -0.000
# ==============================================================================
# Omnibus:                        4.185   Durbin-Watson:                   1.510
# Prob(Omnibus):                  0.123   Jarque-Bera (JB):                4.825
# Skew:                           0.101   Prob(JB):                       0.0896
# Kurtosis:                       3.530   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.294
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.256
# Time:                        16:16:05   Log-Likelihood:                 242.89
# No. Observations:                 360   AIC:                            -481.8
# Df Residuals:                     358   BIC:                            -474.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.8291      0.013    140.703      0.000         1.804     1.855
# windBearing   7.13e-05   6.27e-05      1.138      0.256      -5.2e-05     0.000
# ==============================================================================
# Omnibus:                       12.063   Durbin-Watson:                   1.390
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.655
# Skew:                           0.444   Prob(JB):                      0.00179
# Kurtosis:                       2.763   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     5.353
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0213
# Time:                        16:16:05   Log-Likelihood:                 236.10
# No. Observations:                 360   AIC:                            -468.2
# Df Residuals:                     358   BIC:                            -460.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.1191      0.013     84.480      0.000         1.093     1.145
# windBearing     0.0001   6.39e-05      2.314      0.021      2.22e-05     0.000
# ==============================================================================
# Omnibus:                      147.164   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              501.394
# Skew:                           1.863   Prob(JB):                    1.33e-109
# Kurtosis:                       7.421   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'windSpeed')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                  0.002784
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.958
# Time:                        16:16:06   Log-Likelihood:                -42.603
# No. Observations:                  38   AIC:                             89.21
# Df Residuals:                      36   BIC:                             92.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     12.5799      0.240     52.403      0.000        12.093    13.067
# windSpeed      0.0006      0.011      0.053      0.958        -0.022     0.023
# ==============================================================================
# Omnibus:                        5.537   Durbin-Watson:                   1.476
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                5.930
# Skew:                          -0.298   Prob(JB):                       0.0516
# Kurtosis:                       4.841   Cond. No.                         42.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.361
# Method:                 Least Squares   F-statistic:                     21.89
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           4.00e-05
# Time:                        16:16:06   Log-Likelihood:                -4.2768
# No. Observations:                  38   AIC:                             12.55
# Df Residuals:                      36   BIC:                             15.83
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.8650      0.088     32.721      0.000         2.687     3.043
# windSpeed     -0.0188      0.004     -4.678      0.000        -0.027    -0.011
# ==============================================================================
# Omnibus:                       19.273   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.036
# Skew:                           1.112   Prob(JB):                     4.52e-10
# Kurtosis:                       7.715   Cond. No.                         42.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     55.91
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           9.36e-09
# Time:                        16:16:07   Log-Likelihood:                -1.7210
# No. Observations:                  37   AIC:                             7.442
# Df Residuals:                      35   BIC:                             10.66
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.8537      0.083     34.526      0.000         2.686     3.021
# windSpeed     -0.0290      0.004     -7.477      0.000        -0.037    -0.021
# ==============================================================================
# Omnibus:                       29.154   Durbin-Watson:                   1.526
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.508
# Skew:                          -2.024   Prob(JB):                     1.97e-13
# Kurtosis:                       7.644   Cond. No.                         41.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.3018
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.587
# Time:                        16:16:07   Log-Likelihood:                 11.312
# No. Observations:                  32   AIC:                            -18.62
# Df Residuals:                      30   BIC:                            -15.69
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.0587      0.060     17.567      0.000         0.936     1.182
# windSpeed      0.0018      0.003      0.549      0.587        -0.005     0.009
# ==============================================================================
# Omnibus:                       65.324   Durbin-Watson:                   2.260
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              658.413
# Skew:                           4.405   Prob(JB):                    1.07e-143
# Kurtosis:                      23.401   Cond. No.                         35.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     6.434
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0157
# Time:                        16:16:07   Log-Likelihood:                -44.286
# No. Observations:                  38   AIC:                             92.57
# Df Residuals:                      36   BIC:                             95.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      5.6318      0.251     22.443      0.000         5.123     6.141
# windSpeed     -0.0292      0.012     -2.537      0.016        -0.053    -0.006
# ==============================================================================
# Omnibus:                        3.674   Durbin-Watson:                   0.267
# Prob(Omnibus):                  0.159   Jarque-Bera (JB):                3.116
# Skew:                          -0.700   Prob(JB):                        0.211
# Kurtosis:                       2.909   Cond. No.                         42.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     36.68
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           5.84e-07
# Time:                        16:16:07   Log-Likelihood:                -38.615
# No. Observations:                  38   AIC:                             81.23
# Df Residuals:                      36   BIC:                             84.50
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.9864      0.216      9.190      0.000         1.548     2.425
# windSpeed      0.0601      0.010      6.056      0.000         0.040     0.080
# ==============================================================================
# Omnibus:                        8.674   Durbin-Watson:                   0.891
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                7.445
# Skew:                           0.968   Prob(JB):                       0.0242
# Kurtosis:                       3.976   Cond. No.                         42.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.6883
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.412
# Time:                        16:16:08   Log-Likelihood:                -5.1603
# No. Observations:                  38   AIC:                             14.32
# Df Residuals:                      36   BIC:                             17.60
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.7941      0.090     20.019      0.000         1.612     1.976
# windSpeed      0.0034      0.004      0.830      0.412        -0.005     0.012
# ==============================================================================
# Omnibus:                       11.037   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               28.892
# Skew:                           0.245   Prob(JB):                     5.32e-07
# Kurtosis:                       7.244   Cond. No.                         42.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.368
# Method:                 Least Squares   F-statistic:                     19.07
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           0.000138
# Time:                        16:16:08   Log-Likelihood:                 48.529
# No. Observations:                  32   AIC:                            -93.06
# Df Residuals:                      30   BIC:                            -90.13
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.1793      0.018     63.832      0.000         1.142     1.217
# windSpeed     -0.0044      0.001     -4.367      0.000        -0.006    -0.002
# ==============================================================================
# Omnibus:                        0.327   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.849   Jarque-Bera (JB):                0.391
# Skew:                           0.214   Prob(JB):                        0.822
# Kurtosis:                       2.669   Cond. No.                         35.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'pressure')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     4.082
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0468
# Time:                        16:16:09   Log-Likelihood:                -175.02
# No. Observations:                  79   AIC:                             354.0
# Df Residuals:                      77   BIC:                             358.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -10.9058     11.047     -0.987      0.327       -32.904    11.092
# pressure       0.0222      0.011      2.020      0.047         0.000     0.044
# ==============================================================================
# Omnibus:                       24.888   Durbin-Watson:                   1.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.461
# Skew:                          -1.118   Prob(JB):                     1.82e-11
# Kurtosis:                       6.166   Cond. No.                     4.39e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     13.70
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           0.000410
# Time:                        16:16:09   Log-Likelihood:                -52.887
# No. Observations:                  76   AIC:                             109.8
# Df Residuals:                      74   BIC:                             114.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -7.0274      2.549     -2.757      0.007       -12.107    -1.948
# pressure       0.0094      0.003      3.701      0.000         0.004     0.014
# ==============================================================================
# Omnibus:                        9.476   Durbin-Watson:                   1.396
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               12.115
# Skew:                          -0.538   Prob(JB):                      0.00234
# Kurtosis:                       4.633   Cond. No.                     4.54e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.54e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     17.41
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           8.10e-05
# Time:                        16:16:09   Log-Likelihood:                -46.150
# No. Observations:                  76   AIC:                             96.30
# Df Residuals:                      74   BIC:                             101.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -7.4073      2.336     -3.170      0.002       -12.063    -2.752
# pressure       0.0097      0.002      4.173      0.000         0.005     0.014
# ==============================================================================
# Omnibus:                        9.524   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               18.285
# Skew:                           0.316   Prob(JB):                     0.000107
# Kurtosis:                       5.318   Cond. No.                     4.56e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     2.218
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.142
# Time:                        16:16:09   Log-Likelihood:                 32.254
# No. Observations:                  55   AIC:                            -60.51
# Df Residuals:                      53   BIC:                            -56.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.6432      1.152     -0.559      0.579        -2.953     1.667
# pressure       0.0017      0.001      1.489      0.142        -0.001     0.004
# ==============================================================================
# Omnibus:                       98.616   Durbin-Watson:                   2.306
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2474.384
# Skew:                           5.223   Prob(JB):                         0.00
# Kurtosis:                      34.155   Cond. No.                     6.31e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.31e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     6.133
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0155
# Time:                        16:16:10   Log-Likelihood:                -106.90
# No. Observations:                  78   AIC:                             217.8
# Df Residuals:                      76   BIC:                             222.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -7.0930      4.808     -1.475      0.144       -16.669     2.483
# pressure       0.0118      0.005      2.477      0.015         0.002     0.021
# ==============================================================================
# Omnibus:                       12.426   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               36.614
# Skew:                           0.238   Prob(JB):                     1.12e-08
# Kurtosis:                       6.323   Cond. No.                     4.42e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     11.52
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):            0.00109
# Time:                        16:16:26   Log-Likelihood:                -130.58
# No. Observations:                  78   AIC:                             265.2
# Df Residuals:                      76   BIC:                             269.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     24.9127      6.513      3.825      0.000        11.941    37.885
# pressure      -0.0220      0.006     -3.395      0.001        -0.035    -0.009
# ==============================================================================
# Omnibus:                       76.562   Durbin-Watson:                   0.494
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              617.264
# Skew:                           3.016   Prob(JB):                    9.18e-135
# Kurtosis:                      15.392   Cond. No.                     4.42e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.260
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.265
# Time:                        16:16:26   Log-Likelihood:                -18.495
# No. Observations:                  77   AIC:                             40.99
# Df Residuals:                      75   BIC:                             45.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.0345      1.575     -0.022      0.983        -3.173     3.104
# pressure       0.0018      0.002      1.123      0.265        -0.001     0.005
# ==============================================================================
# Omnibus:                       11.556   Durbin-Watson:                   1.671
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.510
# Skew:                          -0.780   Prob(JB):                      0.00192
# Kurtosis:                       4.211   Cond. No.                     4.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.2094
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.649
# Time:                        16:16:27   Log-Likelihood:                 18.090
# No. Observations:                  62   AIC:                            -32.18
# Df Residuals:                      60   BIC:                            -27.92
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.5705      1.262      0.452      0.653        -1.953     3.094
# pressure       0.0006      0.001      0.458      0.649        -0.002     0.003
# ==============================================================================
# Omnibus:                       63.153   Durbin-Watson:                   2.336
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              364.497
# Skew:                           2.985   Prob(JB):                     7.09e-80
# Kurtosis:                      13.270   Cond. No.                     5.48e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.48e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'precipAccumulation')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     11.13
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):            0.00106
# Time:                        16:16:27   Log-Likelihood:                -441.20
# No. Observations:                 161   AIC:                             886.4
# Df Residuals:                     159   BIC:                             892.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              9.8892      0.354     27.902      0.000         9.189    10.589
# precipAccumulation    -0.4079      0.122     -3.336      0.001        -0.649    -0.166
# ==============================================================================
# Omnibus:                       45.186   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.642
# Skew:                           1.166   Prob(JB):                     3.47e-25
# Kurtosis:                       6.369   Cond. No.                         3.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     6.301
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0132
# Time:                        16:16:28   Log-Likelihood:                -207.79
# No. Observations:                 144   AIC:                             419.6
# Df Residuals:                     142   BIC:                             425.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              2.4239      0.102     23.754      0.000         2.222     2.626
# precipAccumulation    -0.0985      0.039     -2.510      0.013        -0.176    -0.021
# ==============================================================================
# Omnibus:                       42.348   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.709
# Skew:                           1.335   Prob(JB):                     2.98e-18
# Kurtosis:                       5.514   Cond. No.                         3.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     5.613
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0192
# Time:                        16:16:28   Log-Likelihood:                -192.60
# No. Observations:                 143   AIC:                             389.2
# Df Residuals:                     141   BIC:                             395.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              2.2425      0.092     24.408      0.000         2.061     2.424
# precipAccumulation    -0.0802      0.034     -2.369      0.019        -0.147    -0.013
# ==============================================================================
# Omnibus:                       31.595   Durbin-Watson:                   2.454
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.245
# Skew:                           1.163   Prob(JB):                     9.08e-11
# Kurtosis:                       4.532   Cond. No.                         3.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                  0.002326
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.962
# Time:                        16:16:28   Log-Likelihood:                -12.589
# No. Observations:                  26   AIC:                             29.18
# Df Residuals:                      24   BIC:                             31.69
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              1.0991      0.101     10.933      0.000         0.892     1.307
# precipAccumulation    -0.0115      0.239     -0.048      0.962        -0.506     0.482
# ==============================================================================
# Omnibus:                       59.638   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              447.812
# Skew:                           4.414   Prob(JB):                     5.74e-98
# Kurtosis:                      21.315   Cond. No.                         3.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     2.388
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.124
# Time:                        16:16:28   Log-Likelihood:                -308.19
# No. Observations:                 151   AIC:                             620.4
# Df Residuals:                     149   BIC:                             626.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              4.1746      0.183     22.760      0.000         3.812     4.537
# precipAccumulation    -0.1119      0.072     -1.545      0.124        -0.255     0.031
# ==============================================================================
# Omnibus:                       10.019   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.056
# Skew:                           0.600   Prob(JB):                      0.00655
# Kurtosis:                       3.397   Cond. No.                         3.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     2.833
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0945
# Time:                        16:16:29   Log-Likelihood:                -191.91
# No. Observations:                 144   AIC:                             387.8
# Df Residuals:                     142   BIC:                             393.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              2.2357      0.092     24.234      0.000         2.053     2.418
# precipAccumulation    -0.0709      0.042     -1.683      0.095        -0.154     0.012
# ==============================================================================
# Omnibus:                       36.656   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.061
# Skew:                           1.189   Prob(JB):                     7.45e-15
# Kurtosis:                       5.277   Cond. No.                         2.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8009
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.373
# Time:                        16:16:29   Log-Likelihood:                -152.01
# No. Observations:                 127   AIC:                             308.0
# Df Residuals:                     125   BIC:                             313.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              1.7086      0.086     19.965      0.000         1.539     1.878
# precipAccumulation    -0.0395      0.044     -0.895      0.373        -0.127     0.048
# ==============================================================================
# Omnibus:                       49.223   Durbin-Watson:                   1.747
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.570
# Skew:                           1.669   Prob(JB):                     3.24e-23
# Kurtosis:                       5.903   Cond. No.                         2.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.4410
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.509
# Time:                        16:16:29   Log-Likelihood:                -76.616
# No. Observations:                  65   AIC:                             157.2
# Df Residuals:                      63   BIC:                             161.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              1.1719      0.113     10.376      0.000         0.946     1.398
# precipAccumulation    -0.0453      0.068     -0.664      0.509        -0.182     0.091
# ==============================================================================
# Omnibus:                      137.656   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8820.812
# Skew:                           7.425   Prob(JB):                         0.00
# Kurtosis:                      58.104   Cond. No.                         2.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
weatherTypes = ['dewPoint', 'apparentTemperature', 'temperature', 'visibility', 'precipIntensity',
                'windBearing', 'windSpeed', 'pressure', 'precipAccumulation', 'cloudCover']

for i in felonyTypes:
    weatherCorrelation(dfSeven, i, 'cloudCover')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     7.391
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):            0.00774
# Time:                        16:16:30   Log-Likelihood:                -93.280
# No. Observations:                 101   AIC:                             190.6
# Df Residuals:                      99   BIC:                             195.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     12.8704      0.122    105.860      0.000        12.629    13.112
# cloudCover     0.5710      0.210      2.719      0.008         0.154     0.988
# ==============================================================================
# Omnibus:                       11.828   Durbin-Watson:                   0.669
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.467
# Skew:                          -0.742   Prob(JB):                      0.00196
# Kurtosis:                       3.873   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     20.92
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.39e-05
# Time:                        16:16:30   Log-Likelihood:                 76.892
# No. Observations:                 101   AIC:                            -149.8
# Df Residuals:                      99   BIC:                            -144.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.6794      0.023    118.825      0.000         2.635     2.724
# cloudCover     0.1782      0.039      4.574      0.000         0.101     0.255
# ==============================================================================
# Omnibus:                        1.407   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.495   Jarque-Bera (JB):                0.914
# Skew:                          -0.195   Prob(JB):                        0.633
# Kurtosis:                       3.256   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.395
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     64.61
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           1.99e-12
# Time:                        16:16:30   Log-Likelihood:                 93.253
# No. Observations:                 101   AIC:                            -182.5
# Df Residuals:                      99   BIC:                            -177.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.7494      0.019    143.371      0.000         2.711     2.787
# cloudCover    -0.2663      0.033     -8.038      0.000        -0.332    -0.201
# ==============================================================================
# Omnibus:                        3.369   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                2.777
# Skew:                          -0.291   Prob(JB):                        0.249
# Kurtosis:                       3.566   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MURDER & NON-NEGL. MANSLAUGHTER Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     2.616
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.109
# Time:                        16:16:30   Log-Likelihood:                 135.86
# No. Observations:                 101   AIC:                            -267.7
# Df Residuals:                      99   BIC:                            -262.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.0598      0.013     84.268      0.000         1.035     1.085
# cloudCover     0.0351      0.022      1.618      0.109        -0.008     0.078
# ==============================================================================
# Omnibus:                        9.626   Durbin-Watson:                   2.281
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.492
# Skew:                           0.697   Prob(JB):                      0.00869
# Kurtosis:                       3.559   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.887
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.173
# Time:                        16:16:31   Log-Likelihood:                -45.903
# No. Observations:                 101   AIC:                             95.81
# Df Residuals:                      99   BIC:                             101.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      5.3247      0.076     70.009      0.000         5.174     5.476
# cloudCover     0.1805      0.131      1.374      0.173        -0.080     0.441
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   0.535
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.092
# Skew:                          -0.860   Prob(JB):                     1.60e-05
# Kurtosis:                       4.514   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BURGLARY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.321
# Method:                 Least Squares   F-statistic:                     48.29
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           3.95e-10
# Time:                        16:16:31   Log-Likelihood:                 55.660
# No. Observations:                 101   AIC:                            -107.3
# Df Residuals:                      99   BIC:                            -102.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.5239      0.028     90.709      0.000         2.469     2.579
# cloudCover     0.3341      0.048      6.949      0.000         0.239     0.429
# ==============================================================================
# Omnibus:                        5.004   Durbin-Watson:                   1.408
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                4.426
# Skew:                          -0.494   Prob(JB):                        0.109
# Kurtosis:                       3.275   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# GRAND LARCENY OF MOTOR VEHICLE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     6.156
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):             0.0148
# Time:                        16:16:31   Log-Likelihood:                 110.74
# No. Observations:                 101   AIC:                            -217.5
# Df Residuals:                      99   BIC:                            -212.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.8458      0.016    114.445      0.000         1.814     1.878
# cloudCover     0.0691      0.028      2.481      0.015         0.014     0.124
# ==============================================================================
# Omnibus:                        6.155   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.645
# Skew:                          -0.560   Prob(JB):                       0.0595
# Kurtosis:                       3.295   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RAPE Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.6542
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.421
# Time:                        16:16:31   Log-Likelihood:                 82.239
# No. Observations:                 101   AIC:                            -160.5
# Df Residuals:                      99   BIC:                            -155.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.1342      0.021     53.032      0.000         1.092     1.177
# cloudCover     0.0299      0.037      0.809      0.421        -0.043     0.103
# ==============================================================================
# Omnibus:                       53.963   Durbin-Watson:                   2.234
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              179.005
# Skew:                           1.882   Prob(JB):                     1.35e-39
# Kurtosis:                       8.327   Cond. No.                         4.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Reducing to outdoor crimes only

# %%
maybeOutdoor = ['STREET', 'PARK/PLAYGROUND', 'PARKING LOT/GARAGE (PUBLIC)', 'GAS STATION', 'TUNNEL',
       'TRANSIT - NYC SUBWAY', 'BUS (NYC TRANSIT)', 'PARKING LOT/GARAGE (PRIVATE)',
       'FERRY/FERRY TERMINAL', 'CONSTRUCTION SITE', 'BUS STOP', 'BRIDGE', 'OPEN AREAS (OPEN LOTS)', 'MARINA/PIER',
       'HIGHWAY/PARKWAY', 'BUS TERMINAL', 'CEMETERY', 'TRAMWAY']

outdoor = ['STREET', 'PARK/PLAYGROUND', 'TUNNEL', 'CONSTRUCTION SITE', 'BUS STOP', 'BRIDGE', 'OPEN AREAS (OPEN LOTS)',
           'MARINA/PIER', 'HIGHWAY/PARKWAY', 'BUS TERMINAL', 'CEMETERY']

dfSevenOutdoor = dfSeven.loc[dfSeven['PREM_TYP_DESC'].isin(maybeOutdoor)]

# %%
dfSevenOutdoor.head()
# Out:
#     level_0  index  CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 2        12     12   898496564   12/31/2015     23:00:00          NaN
# 3        13     13   566081066   12/31/2015     23:00:00          NaN
# 9        34     34   590638275   12/31/2015     22:30:00          NaN
# 11       38     38   448659551   12/31/2015     22:25:00          NaN
# 12       40     40   221366121   12/31/2015     22:20:00   12/31/2015
#
#    CMPLNT_TO_TM      RPT_DT  KY_CD       OFNS_DESC         ...          \
# 2           NaN  12/31/2015    109   GRAND LARCENY         ...
# 3           NaN  12/31/2015    109   GRAND LARCENY         ...
# 9           NaN  12/31/2015    106  FELONY ASSAULT         ...
# 11          NaN  12/31/2015    106  FELONY ASSAULT         ...
# 12     22:30:00  12/31/2015    105         ROBBERY         ...
#
#     precipType pressure        summary temperature          time visibility  \
# 2          NaN   1019.0          Clear        43.0  1.451621e+09       10.0
# 3          NaN   1019.0          Clear        43.0  1.451621e+09       10.0
# 9          NaN   1019.0          Clear        43.0  1.451621e+09       10.0
# 11         NaN   1019.0  Mostly Cloudy        44.0  1.451617e+09       10.0
# 12         NaN   1019.0  Mostly Cloudy        44.0  1.451617e+09       10.0
#
#     windBearing windSpeed          datetime_y        datetime_adj
# 2         308.0      10.0 2016-01-01 04:00:00 2015-12-31 23:00:00
# 3         308.0      10.0 2016-01-01 04:00:00 2015-12-31 23:00:00
# 9         308.0      10.0 2016-01-01 04:00:00 2015-12-31 23:00:00
# 11        313.0      13.0 2016-01-01 03:00:00 2015-12-31 22:00:00
# 12        313.0      13.0 2016-01-01 03:00:00 2015-12-31 22:00:00
#
# [5 rows x 48 columns]

# %% [markdown]
# ### There's an issue here where we cannot reset the index of the new dataframe... this is impacting the ability to run through the function we created, which requires the index to reset... for some reason, it DOES still work for certain types of crime (all, robbery, and felony assault)

# %%
for i in felonyTypes:
    weatherCorrelation(dfSevenOutdoor, i, 'windBearing')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.705
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.192
# Time:                        16:16:42   Log-Likelihood:                -286.68
# No. Observations:                 360   AIC:                             577.4
# Df Residuals:                     358   BIC:                             585.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       5.2040      0.057     91.949      0.000         5.093     5.315
# windBearing     0.0004      0.000      1.306      0.192        -0.000     0.001
# ==============================================================================
# Omnibus:                       32.374   Durbin-Watson:                   0.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.827
# Skew:                           0.503   Prob(JB):                     1.10e-05
# Kurtosis:                       2.285   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ROBBERY Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     7.150
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):            0.00784
# Time:                        16:16:42   Log-Likelihood:                 213.66
# No. Observations:                 360   AIC:                            -423.3
# Df Residuals:                     358   BIC:                            -415.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       2.0754      0.014    147.198      0.000         2.048     2.103
# windBearing     0.0002    6.8e-05      2.674      0.008      4.81e-05     0.000
# ==============================================================================
# Omnibus:                       12.594   Durbin-Watson:                   1.455
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.000
# Skew:                           0.375   Prob(JB):                     0.000912
# Kurtosis:                       3.609   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FELONY ASSAULT Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.902
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.169
# Time:                        16:16:42   Log-Likelihood:                 233.00
# No. Observations:                 360   AIC:                            -462.0
# Df Residuals:                     358   BIC:                            -454.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       1.6671      0.013    124.766      0.000         1.641     1.693
# windBearing  8.885e-05   6.44e-05      1.379      0.169     -3.78e-05     0.000
# ==============================================================================
# Omnibus:                       12.819   Durbin-Watson:                   1.402
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.365
# Skew:                           0.421   Prob(JB):                      0.00125
# Kurtosis:                       3.428   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-05ac1dd81ec0> in <module>()
#       1 for i in felonyTypes:
# ----> 2     weatherCorrelation(dfSevenOutdoor, i, 'windBearing')
#
# <ipython-input-39-efd072b4ad50> in weatherCorrelation(dataframe, crime, weatherType)
#      44     # Fit a regression model
#      45
# ---> 46     weatherMod = smf.ols("CrimePerHour ~ " + weatherType, data=dfWeatherNormalized)
#      47     weatherFit = weatherMod.fit()
#      48     weatherFitLine = weatherFit.fittedvalues
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, *args, **kwargs)
#     148         kwargs.update({'missing_idx': missing_idx,
#     149                        'missing': missing})
# --> 150         mod = cls(endog, exog, *args, **kwargs)
#     151         mod.formula = formula
#     152
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     689                  **kwargs):
#     690         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 691                                   hasconst=hasconst, **kwargs)
#     692         if "weights" in self._init_keys:
#     693             self._init_keys.remove("weights")
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     584             weights = weights.squeeze()
#     585         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 586                                   weights=weights, hasconst=hasconst, **kwargs)
#     587         nobs = self.exog.shape[0]
#     588         weights = self.weights
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#      89     """
#      90     def __init__(self, endog, exog, **kwargs):
# ---> 91         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#      92         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#      93
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     184
#     185     def __init__(self, endog, exog=None, **kwargs):
# --> 186         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     187         self.initialize()
#     188
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      58         hasconst = kwargs.pop('hasconst', None)
#      59         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 60                                       **kwargs)
#      61         self.k_constant = self.data.k_constant
#      62         self.exog = self.data.exog
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      82
#      83     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 84         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      85         # kwargs arrays could have changed, easier to just attach here
#      86         for key in kwargs:
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     564     klass = handle_data_class_factory(endog, exog)
#     565     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 566                  **kwargs)
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      73
#      74         # this has side-effects, attaches k_constant and const_idx
# ---> 75         self._handle_constant(hasconst)
#      76         self._check_integrity()
#      77         self._cache = resettable_cache()
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#      91             # detect where the constant is
#      92             check_implicit = False
# ---> 93             const_idx = np.where(self.exog.ptp(axis=0) == 0)[0].squeeze()
#      94             self.k_constant = const_idx.size
#      95
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
weatherCorrelation(dfSevenOutdoor, 'ALL CRIME', 'windBearing')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.705
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):              0.192
# Time:                        16:42:42   Log-Likelihood:                -286.68
# No. Observations:                 360   AIC:                             577.4
# Df Residuals:                     358   BIC:                             585.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       5.2040      0.057     91.949      0.000         5.093     5.315
# windBearing     0.0004      0.000      1.306      0.192        -0.000     0.001
# ==============================================================================
# Omnibus:                       32.374   Durbin-Watson:                   0.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.827
# Skew:                           0.503   Prob(JB):                     1.10e-05
# Kurtosis:                       2.285   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7ff0806493c8>,
#  [<matplotlib.lines.Line2D at 0x7ff08064f128>])

# %% [markdown]
# ### Examining temperature and wind bearing for correlation

# %%
dfSeven.plot.scatter(x='temperature', y='windBearing');

# %% [markdown]
# This is kind of messy...let's take a random sampling of every 3000th row

# %%
dfSample = dfSeven.iloc[::3000, :]

# %%
dfSample.plot.scatter(x='temperature', y='windBearing');

# %% [markdown]
# This shows us with a little more definition that southern winds are less likely to occur at lower temperatures. What would happen if we plot crimes that happen at 20 degrees (or higher), eliminating this hole?

# %%
dvSevenHigherTemps = dfSeven[(dfSeven['temperature'] >= 40)]

# %%
dfSevenHigherTempsSample = dvSevenHigherTemps.iloc[::3000, :]
dfSevenHigherTempsSample.plot.scatter(x='temperature', y='windBearing');

# %% [markdown]
# Still looks pretty randomly distributed to me...

# %%
weatherCorrelation(dvSevenHigherTemps, 'ALL CRIME', 'windBearing')
# Out:
# ALL CRIME Regression Results:
#
#
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           CrimePerHour   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     17.81
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):           3.10e-05
# Time:                        16:17:18   Log-Likelihood:                -439.79
# No. Observations:                 360   AIC:                             883.6
# Df Residuals:                     358   BIC:                             891.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept      12.8107      0.087    147.937      0.000        12.640    12.981
# windBearing     0.0018      0.000      4.220      0.000         0.001     0.003
# ==============================================================================
# Omnibus:                        9.836   Durbin-Watson:                   0.567
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                9.283
# Skew:                           0.344   Prob(JB):                      0.00964
# Kurtosis:                       2.617   Cond. No.                         414.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7ff07ff76ef0>,
#  [<matplotlib.lines.Line2D at 0x7ff07fe8c550>])

# %% [markdown]
# Limiting our data to higher temperatures (as high as 40) still leaves us with a visible correlation... what else could account for this? Maybe it's a temporal correlation, with southern winds occuring more frequently in the summer.

# %% [markdown]
# ## Time Series Analysis of wind bearing

# %%
weather.head()
# Out:
#    apparentTemperature  cloudCover  dewPoint  humidity                 icon  \
# 0                26.80        0.82     28.43      0.85  partly-cloudy-night
# 1                27.04        0.77     28.32      0.85  partly-cloudy-night
# 2                27.21        0.78     28.34      0.85  partly-cloudy-night
# 3                27.01        0.34     27.97      0.84  partly-cloudy-night
# 4                26.65        0.95     28.10      0.85               cloudy
#
#    precipAccumulation  precipIntensity  precipProbability precipType  \
# 0                 NaN              0.0                0.0        NaN
# 1                 NaN              0.0                0.0        NaN
# 2                 NaN              0.0                0.0        NaN
# 3                 NaN              0.0                0.0        NaN
# 4                 NaN              0.0                0.0        NaN
#
#    pressure        summary  temperature        time  visibility  windBearing  \
# 0   1009.73  Mostly Cloudy        32.48  1136091600        8.84        335.0
# 1   1010.35  Mostly Cloudy        32.33  1136095200        7.67        345.0
# 2   1011.40  Mostly Cloudy        32.29  1136098800        8.69        344.0
# 3   1012.17  Partly Cloudy        32.19  1136102400        8.79        345.0
# 4   1012.67       Overcast        32.00  1136106000        8.41        339.0
#
#    windSpeed            datetime        datetime_adj
# 0       6.00 2006-01-01 05:00:00 2006-01-01 00:00:00
# 1       5.49 2006-01-01 06:00:00 2006-01-01 01:00:00
# 2       5.23 2006-01-01 07:00:00 2006-01-01 02:00:00
# 3       5.32 2006-01-01 08:00:00 2006-01-01 03:00:00
# 4       5.49 2006-01-01 09:00:00 2006-01-01 04:00:00

# %%
weather['month'] = weather['datetime_adj'].dt.month

# %%
fourDays = weather.iloc[0:96]
dailyWeather = weather.iloc[::24, :]
dailyWeatherOneYear = dailyWeather.iloc[0:365]
dailyWeatherTwoYears = dailyWeather.iloc[0:730]
weeklyWeather = dailyWeather.iloc[::7, :]
weeklyWeatherOneyear = weeklyWeather.iloc[0:52]

# %%
dailyWeatherOneYear.plot(x='datetime_adj', y='windBearing');
dailyWeatherTwoYears.plot(x='datetime_adj', y='windBearing');
# The above are misleading... you need them plotted as points -- the lines make it look continuous,
# but you aren't looking at continuous data... you selected every 24 hours

dailyWeatherOneYear.plot.scatter(x='month', y='windBearing');
dailyWeatherTwoYears.plot.scatter(x='month', y='windBearing');
weeklyWeatherOneyear.plot(x='datetime_adj', y='windBearing');
fourDays.plot(x='datetime_adj', y='windBearing');

# %% [markdown]
# #### Looking at data for 365 continuous days, 730 continuous days, and 52 continuous weeks, there isn't a discernable temporal distribution of wind bearing. There are small holes here and there, but those do not appear to be based on any discernable pattern.

# %% [markdown]
# # Mapping Crime

# %%
import choroplethNYC as cp
import geopandas as gpd
from shapely.geometry import Point
from geopandas import GeoDataFrame

# %%
#cp.choroplethNYC(geoFelony, column='KMClusterNumbers', color="white", edgecolor="black", lw=2)

# %%
# Filter out crimes that occur when wind is not coming from the south
dfSouth = dfSeven.loc[(dfSeven['windBearing'] >= 160) & (dfSeven['windBearing'] <= 200)]

# %%
dfSouth.columns
# Out:
# Index(['level_0', 'index', 'CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon', 'year', 'hour', 'datetime_x', 'datetime_round',
#        'apparentTemperature', 'cloudCover', 'dewPoint', 'humidity', 'icon',
#        'precipAccumulation', 'precipIntensity', 'precipProbability',
#        'precipType', 'pressure', 'summary', 'temperature', 'time',
#        'visibility', 'windBearing', 'windSpeed', 'datetime_y', 'datetime_adj'],
#       dtype='object')

# %%
dfSouth['ADDR_PCT_CD']
# Out:
# 248         13.0
# 269         20.0
# 273         18.0
# 274        103.0
# 522         13.0
# 523         34.0
# 528         13.0
# 529        109.0
# 530        120.0
# 531         79.0
# 570         40.0
# 764         17.0
# 794         49.0
# 815        104.0
# 816         68.0
# 817         75.0
# 818         18.0
# 819         17.0
# 839         23.0
# 873        123.0
# 1096         1.0
# 1097        71.0
# 1098        25.0
# 1099       102.0
# 1102        81.0
# 1105       103.0
# 1106        63.0
# 1118        52.0
# 1119        73.0
# 1120        18.0
#            ...
# 1217238    114.0
# 1217239     34.0
# 1217411     14.0
# 1217414     13.0
# 1217419     67.0
# 1217431     67.0
# 1217435    113.0
# 1217678     34.0
# 1217696     41.0
# 1217718     77.0
# 1217725     14.0
# 1217925    120.0
# 1217931     88.0
# 1217932     63.0
# 1217943    111.0
# 1217952     10.0
# 1217963     40.0
# 1217970     18.0
# 1218227      9.0
# 1218238     44.0
# 1218243     26.0
# 1218252     34.0
# 1218258     78.0
# 1218265     47.0
# 1218510    108.0
# 1218515     50.0
# 1218765     72.0
# 1218773     34.0
# 1218775     44.0
# 1219087     73.0
# Name: ADDR_PCT_CD, dtype: float64

# %%
geometry = [Point(xy) for xy in zip(dfSouth.Longitude, dfSouth.Latitude)]
dfSouth = dfSouth.drop(['Longitude', 'Latitude'], axis=1)
crs = {'init': 'epsg:4326'}
gdf = GeoDataFrame(dfSouth, crs=crs, geometry=geometry)

# %%
gdf.head()
# Out:
#      level_0  index  CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 248      986    986   315719041   12/22/2015     08:00:00   12/28/2015
# 269     1080   1080   784751273   07/17/2015     00:01:00   07/24/2015
# 273     1089   1089   304095347   09/27/2014     20:51:00          NaN
# 274     1092   1092   840272043   08/19/2011     12:00:00   12/31/2015
# 522     2173   2174   582920285   12/24/2015     00:01:00          NaN
#
#     CMPLNT_TO_TM      RPT_DT  KY_CD      OFNS_DESC  \
# 248     13:00:00  12/31/2015    109  GRAND LARCENY
# 269     23:59:00  12/31/2015    109  GRAND LARCENY
# 273          NaN  12/31/2015    109  GRAND LARCENY
# 274     11:00:00  12/31/2015    107       BURGLARY
# 522          NaN  12/30/2015    109  GRAND LARCENY
#
#                          ...                       pressure        summary  \
# 248                      ...                         1017.0          Clear
# 269                      ...                         1018.0          Clear
# 273                      ...                         1021.0          Clear
# 274                      ...                         1014.0  Partly Cloudy
# 522                      ...                         1010.0          Clear
#
#     temperature          time visibility windBearing  windSpeed  \
# 248        54.0  1.450789e+09        9.8       176.0        6.0
# 269        69.0  1.437106e+09       10.0       199.0        6.0
# 273        73.0  1.411866e+09       10.0       187.0        4.0
# 274        78.0  1.313770e+09        9.4       195.0        5.0
# 522        62.0  1.450933e+09        4.2       187.0       10.0
#
#              datetime_y        datetime_adj  \
# 248 2015-12-22 13:00:00 2015-12-22 08:00:00
# 269 2015-07-17 04:00:00 2015-07-17 00:00:00
# 273 2014-09-28 01:00:00 2014-09-27 21:00:00
# 274 2011-08-19 16:00:00 2011-08-19 12:00:00
# 522 2015-12-24 05:00:00 2015-12-24 00:00:00
#
#                                          geometry
# 248       POINT (-73.98847201699999 40.739402283)
# 269        POINT (-73.98356551100001 40.77855547)
# 273  POINT (-73.99045573399999 40.77162029300001)
# 274            POINT (-73.785240235 40.701226017)
# 522             POINT (-73.97490979 40.732908785)
#
# [5 rows x 47 columns]
